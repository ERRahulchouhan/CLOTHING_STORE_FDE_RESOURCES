# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi

# %%
# uri = "mongodb+srv://rahulsayon90_db_user:TcGatyiNibSR97cV@learning-db.ak3fech.mongodb.net/"

uri="mongodb+srv://rahulsayon92_db_user:rOR6r71uCCEJAHmK@clothstore.d9u6nih.mongodb.net/"
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client["ecom_db"]

collection = db["orders"]

print("order collection inilitalized")
# Out:
# order collection inilitalized

# %%
order = {
    "name" : "Baggy Jeans",
    "price" : 999 , 
    "category" : ["Men" , "Women" , "Kids"]
}

order
# Out:
# {'name': 'Baggy Jeans', 'price': 999, 'category': ['Men', 'Women', 'Kids']}

# %%
type(order)
# Out:
# dict

# %%
collection.insert_one(order)
# Out:
# InsertOneResult(ObjectId('6ab5538aea0f012c2c1a530c'), acknowledged=True)

# %% [markdown]
# CRUD

# %%
collection = db["products"]

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)
# Out:
# InsertManyResult([ObjectId('6ab5538eea0f012c2c1a530d'), ObjectId('6ab5538eea0f012c2c1a530e'), ObjectId('6ab5538eea0f012c2c1a530f')], acknowledged=True)

# %% [markdown]
# FIND - read

# %%
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6ab5538eea0f012c2c1a530d'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('6ab5538eea0f012c2c1a530e'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('6ab5538eea0f012c2c1a530f'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %% [markdown]
# TEXT 2 NOSQL

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('6ab5538eea0f012c2c1a530e'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "men"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('6ab5538eea0f012c2c1a530d'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}

# %% [markdown]
# UPDATE

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅

# %% [markdown]
# DELETE

# %%
collection.delete_one({"name": "Kids Jacket"})

print("Product Deleted ✅")
# Out:
# Product Deleted ✅

# %%
collection.delete_many({})

print("All Products Deleted ✅")
# Out:
# All Products Deleted ✅

# %%
collection.drop()

print("Collection Dropped ✅")
# Out:
# Collection Dropped ✅
